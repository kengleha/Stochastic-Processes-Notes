# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Values for lambda
lambdas = [2, 3]

# Generate x values
x_values = np.arange(0, 11)

# Plotting
plt.figure(figsize=(10, 6))
for lam in lambdas:
    # Calculate PMF for each lambda
    pmf = poisson.pmf(x_values, lam)
    plt.stem(x_values, pmf, label=f'λ = {lam}')

plt.title('Poisson Distribution')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.xticks(x_values)
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Values for lambda
lambdas = [2, 4]

# Generate x values with 50 points in between 0 and 11
x_values = np.linspace(0, 11, 11)

# Plotting
plt.figure(figsize=(10, 6))
for lam in lambdas:
    # Calculate PMF for each lambda
    pmf = poisson.pmf(x_values, lam)
    plt.plot(x_values, pmf, label=f'λ = {lam}')

plt.title('Poisson Distribution')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.xticks(np.arange(0, 16, 1))
plt.legend()
plt.grid(True)
plt.show()

# %%
x_values
# Out:
# array([ 0.        ,  1.22222222,  2.44444444,  3.66666667,  4.88888889,
#         6.11111111,  7.33333333,  8.55555556,  9.77777778, 11.        ])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Values for lambda
lambdas = [2, 3]

# Generate x values
x_values = np.arange(0, 11)

# Plotting
plt.figure(figsize=(10, 6))
for lam in lambdas:
    # Calculate PMF for each lambda
    pmf = poisson.pmf(x_values, lam)
    plt.stem(x_values, pmf, label=f'λ = {lam}', basefmt=" ", use_line_collection=True)

plt.title('Poisson Distribution')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.xticks(x_values)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/dg/52hsjgqx35sdp0lyrfrkhwbr0000gr/T/ipykernel_25851/3983904510.py:16: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x_values, pmf, label=f'λ = {lam}', basefmt=" ", use_line_collection=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Values for lambda
lambdas = [2, 4]

# Generate x values
x_values = np.arange(0, 11)

# Plotting
plt.figure(figsize=(10, 6))
for i, lam in enumerate(lambdas):
    # Calculate PMF for each lambda
    pmf = poisson.pmf(x_values, lam)
    plt.stem(x_values+(i)*0.1, pmf, linefmt=f'C{i}', markerfmt=f'C{i}o', label=f'λ = {lam}', basefmt=" ", use_line_collection=True)

#plt.title('Poisson Distribution')
plt.xlabel('Number of Events, k')
plt.ylabel('$f_x(X=k)$')
plt.xticks(x_values)
plt.legend()
#plt.grid(True)
plt.show()
# Out:
# /var/folders/dg/52hsjgqx35sdp0lyrfrkhwbr0000gr/T/ipykernel_25851/3186335261.py:16: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x_values+(i)*0.1, pmf, linefmt=f'C{i}', markerfmt=f'C{i}o', label=f'λ = {lam}', basefmt=" ", use_line_collection=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Number of tosses
n = 5

# Possible outcomes
x_values = np.arange(0, n+1)

# Probability of success (fair coin toss)
p = 0.5

# Calculate PMF for binomial distribution
pmf = binom.pmf(x_values, n, p)

# Plotting
plt.figure(figsize=(8, 5))
plt.stem(x_values, pmf, align='center', alpha=0.7)
plt.title('PMF of Fair Coin Toss for n=5')
plt.xlabel('Number of Heads')
plt.ylabel('Probability')
plt.xticks(x_values)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 19
#      17 # Plotting
#      18 plt.figure(figsize=(8, 5))
# ---> 19 plt.stem(x_values, pmf, align='center', alpha=0.7)
#      20 plt.title('PMF of Fair Coin Toss for n=5')
#      21 plt.xlabel('Number of Heads')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:384, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     379 @functools.wraps(func)
#     380 def wrapper(*inner_args, **inner_kwargs):
#     381     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     382         # Early return in the simple, non-deprecated case (much faster than
#     383         # calling bind()).
# --> 384         return func(*inner_args, **inner_kwargs)
#     385     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Number of tosses
n = 5

# Possible outcomes
x_values = np.arange(0, n+1)

# Probability of success (fair coin toss)
p = 0.5

# Calculate PMF for binomial distribution
pmf = binom.pmf(x_values, n, p)

# Plotting
plt.figure(figsize=(8, 5))
plt.stem(x_values, pmf, linefmt='b-', markerfmt='bo', basefmt=' ', use_line_collection=True)
#plt.title('PMF of Fair Coin Toss for n=5')
plt.xlabel('Number of Heads, k')
plt.ylabel('$f_x(X=k)$')
plt.xticks(x_values)
#plt.grid(True)
plt.show()
# Out:
# /var/folders/dg/52hsjgqx35sdp0lyrfrkhwbr0000gr/T/ipykernel_25851/3390807665.py:19: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x_values, pmf, linefmt='b-', markerfmt='bo', basefmt=' ', use_line_collection=True)

# %%
import numpy as np
from scipy.stats import multivariate_normal

# Means
mean_x = 3
mean_y = 2

# Variances
variance_x = 4
variance_y = 1

# Covariance
covariance_xy = 1.5

# Create covariance matrix
cov_matrix = np.array([[variance_x, covariance_xy],
                       [covariance_xy, variance_y]])

# Create mean vector
mean_vector = np.array([mean_x, mean_y])

# Define the multivariate normal distribution
multivar_normal = multivariate_normal(mean=mean_vector, cov=cov_matrix)

# Define the range of X and Y values
x_range = np.linspace(1, 5, 100)
y_range = np.linspace(1, 3, 100)

# Calculate the probability
probability = multivar_normal.cdf([5, 3]) - multivar_normal.cdf([1, 1])

print("Probability:", probability)
# Out:
# Probability: 0.6826894921370861

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Means
mean_x = 3
mean_y = 2

# Variances
variance_x = 4
variance_y = 1

# Covariance
covariance_xy = 1.5

# Create covariance matrix
cov_matrix = np.array([[variance_x, covariance_xy],
                       [covariance_xy, variance_y]])

# Create mean vector
mean_vector = np.array([mean_x, mean_y])

# Define the multivariate normal distribution
multivar_normal = multivariate_normal(mean=mean_vector, cov=cov_matrix)

# Define the range of X and Y values
x_range = np.linspace(1, 5, 100)
y_range = np.linspace(1, 3, 100)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the joint PDF values
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y
Z = multivar_normal.pdf(pos)

# Plot the joint PDF
plt.figure(figsize=(8, 6))
plt.contourf(X, Y, Z, cmap='Blues')
plt.colorbar(label='Density')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Joint Gaussian PDF')
plt.xlim(1, 5)
plt.ylim(1, 3)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from scipy.integrate import dblquad

# Means
mean_x = 3
mean_y = 2

# Variances
variance_x = 4
variance_y = 1

# Covariance
covariance_xy = 1.5

# Create covariance matrix
cov_matrix = np.array([[variance_x, covariance_xy],
                       [covariance_xy, variance_y]])

# Create mean vector
mean_vector = np.array([mean_x, mean_y])

# Define the multivariate normal distribution
multivar_normal = multivariate_normal(mean=mean_vector, cov=cov_matrix)

# Define the range of X and Y values
x_range = np.linspace(1, 5, 100)
y_range = np.linspace(1, 3, 100)
X, Y = np.meshgrid(x_range, y_range)




# Calculate the joint PDF values
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y
Z = multivar_normal.pdf(pos)



# Compute the area under the PDF
area, error = dblquad(lambda y, x: multivar_normal.pdf([x, y]), 1, 5, lambda x: 1, lambda x: 3)

# Plot the joint PDF as a mesh plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='Blues')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('$f_{xy}$')
ax.set_title('Joint Gaussian PDF')
plt.show()

print("Area under the PDF:", area)
# Out:
# Area under the PDF: 0.5467057924601146

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from scipy.integrate import dblquad

# Means
mean_x = 3
mean_y = 2

# Variances
variance_x = 4
variance_y = 1

# Covariance
covariance_xy = 1.5

# Create covariance matrix
cov_matrix = np.array([[variance_x, covariance_xy],
                       [covariance_xy, variance_y]])

# Create mean vector
mean_vector = np.array([mean_x, mean_y])

# Define the multivariate normal distribution
multivar_normal = multivariate_normal(mean=mean_vector, cov=cov_matrix)

# Define the range of X and Y values
x_range = np.linspace(1, 5, 100)
y_range = np.linspace(1, 3, 100)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the joint PDF values
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y
Z = multivar_normal.pdf(pos)

# Compute the area under the PDF
area, error = dblquad(lambda y, x: multivar_normal.pdf([x, y]), 1, 5, lambda x: 1, lambda x: 3)

# Plot the joint PDF as a mesh plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='Blues')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('PDF', labelpad=-15)  # Adjust the label position
plt.show()

print("Area under the PDF:", area)
# Out:
# Area under the PDF: 0.5467057924601146

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from scipy.integrate import dblquad

# Means
mean_x = 3
mean_y = 2

# Variances
variance_x = 4
variance_y = 1

# Covariance
covariance_xy = 1.5

# Create covariance matrix
cov_matrix = np.array([[variance_x, covariance_xy],
                       [covariance_xy, variance_y]])

# Create mean vector
mean_vector = np.array([mean_x, mean_y])

# Define the multivariate normal distribution
multivar_normal = multivariate_normal(mean=mean_vector, cov=cov_matrix)

# Define the range of X and Y values
x_range = np.linspace(1, 5, 100)
y_range = np.linspace(1, 3, 100)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the joint PDF values
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y
Z = multivar_normal.pdf(pos)

# Compute the area under the PDF
area, error = dblquad(lambda y, x: multivar_normal.pdf([x, y]), 1, 5, lambda x: 1, lambda x: 3)

# Plot the joint PDF as a mesh plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='Blues')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('PDF', labelpad=-15)  # Adjust the label position
plt.show()

print("Area under the PDF:", area)
# Out:
# Area under the PDF: 0.5467057924601146

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from scipy.integrate import dblquad

# Means
mean_x = 3
mean_y = 2

# Variances
variance_x = 4
variance_y = 1

# Covariance
covariance_xy = 1.5

# Create covariance matrix
cov_matrix = np.array([[variance_x, covariance_xy],
                       [covariance_xy, variance_y]])

# Create mean vector
mean_vector = np.array([mean_x, mean_y])

# Define the multivariate normal distribution
multivar_normal = multivariate_normal(mean=mean_vector, cov=cov_matrix)

# Define the range of X and Y values
x_range = np.linspace(1, 5, 100)
y_range = np.linspace(1, 3, 100)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the joint PDF values
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y
Z = multivar_normal.pdf(pos)

# Compute the area under the PDF
area, error = dblquad(lambda y, x: multivar_normal.pdf([x, y]), 1, 5, lambda x: 1, lambda x: 3)

# Plot the joint PDF as a mesh plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='Blues')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('PDF', labelpad=-15)  # Adjust the label position
plt.show()

print("Area under the PDF:", area)
# Out:
# Area under the PDF: 0.5467057924601146

# %%
generate a real-world example of the CLT
# Out:
#   Cell In[135], line 1
#     generate a real-world example of the CLT
#              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate EMI from different sources
num_samples = 1000
mobile_phone_emi = np.random.normal(loc=-70, scale=5, size=num_samples)  # dBm
lightning_emi = np.random.poisson(lam=10, size=num_samples)  # Strikes per hour
solar_flare_emi = np.random.power(a=2, size=num_samples)  # Power-law distribution
microwave_emi = np.random.gamma(shape=2, scale=10, size=num_samples)  # Watts
ignition_emi = np.random.uniform(low=0, high=5, size=num_samples)  # Spark timing

# Total EMI (sum of contributions)
total_emi = mobile_phone_emi + lightning_emi + solar_flare_emi + microwave_emi + ignition_emi

# Plot the distribution of total EMI
plt.figure(figsize=(8, 6))
plt.hist(total_emi, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Total EMI Level (arbitrary units)')
plt.ylabel('Frequency')
plt.title('Distribution of Total EMI')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the diamonds dataset
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')

# Extract depths for different cuts
x1 = df.loc[df.cut == 'Ideal', ['depth']]
x2 = df.loc[df.cut == 'Fair', ['depth']]
x3 = df.loc[df.cut == 'Good', ['depth']]

# Create subplots for individual distributions
fig, axes = plt.subplots(1, 3, figsize=(10, 3), sharey=True, dpi=100)

# Plot individual distributions
sns.distplot(x1, color='dodgerblue', ax=axes[0], axlabel='Ideal')
sns.distplot(x2, color='deeppink', ax=axes[1], axlabel='Fair')
sns.distplot(x3, color='gold', ax=axes[2], axlabel='Good')

# Set x-axis limits
plt.xlim(50, 75)

# Show the plot
plt.show()
# Out:
# /var/folders/dg/52hsjgqx35sdp0lyrfrkhwbr0000gr/T/ipykernel_25851/3800207367.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x1, color='dodgerblue', ax=axes[0], axlabel='Ideal')
# /var/folders/dg/52hsjgqx35sdp0lyrfrkhwbr0000gr/T/ipykernel_25851/3800207367.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate EMI from different sources
num_samples = 10000
mobile_phone_emi = np.random.normal(loc=-0, scale=5, size=num_samples)  # dBm
lightning_emi = np.random.poisson(lam=10, size=num_samples)  # Strikes per hour
solar_flare_emi = np.random.power(a=2, size=num_samples)  # Power-law distribution
microwave_emi = np.random.gamma(shape=2, scale=10, size=num_samples)  # Watts
ignition_emi = np.random.uniform(low=0, high=5, size=num_samples)  # Spark timing

# Plot the distribution of each EMI separately
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.hist([mobile_phone_emi, lightning_emi, solar_flare_emi, microwave_emi, ignition_emi], bins=10, color=['dodgerblue', 'deeppink', 'gold', 'green', 'orange'], label=['Mobile Phone', 'Lightning', 'Solar Flare', 'Microwave', 'Ignition'], edgecolor='white', alpha=1)
plt.xlabel('EMI Level')
plt.ylabel('Frequency')
plt.title('Distribution of Each EMI Source')
plt.legend()
plt.grid(True)

# Plot the distribution of total EMI
plt.subplot(1, 2, 2)
total_emi = mobile_phone_emi + lightning_emi + solar_flare_emi + microwave_emi + ignition_emi
plt.hist(total_emi, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Total EMI Level (arbitrary units)')
plt.ylabel('Frequency')
plt.title('Distribution of Total EMI')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.hist([solar_flare_emi])
# Out:
# (array([ 114.,  288.,  503.,  694.,  955., 1119., 1339., 1463., 1685.,
#         1840.]),
#  array([0.00853936, 0.10768391, 0.20682845, 0.305973  , 0.40511755,
#         0.5042621 , 0.60340665, 0.7025512 , 0.80169575, 0.9008403 ,
#         0.99998485]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate sample data for EMI levels from different sources
np.random.seed(0)  # for reproducibility
num_samples = [10, 50, 100, 500]  # Different sample sizes

# Simulate EMI levels for different sources
emi_sources = {
    'Lightning': np.random.poisson(lam=10, size=(1000, max(num_samples))),  # Strikes per hour
    'Solar Flare': np.random.power(a=2, size=(1000, max(num_samples))),    # Power-law distribution
    'Mobile Phone': np.random.normal(loc=-70, scale=5, size=(1000, max(num_samples))),  # dBm
    'Microwave': np.random.gamma(shape=2, scale=10, size=(1000, max(num_samples))),   # Watts
    'Ignition': np.random.uniform(low=0, high=5, size=(1000, max(num_samples)))       # Spark timing
}

# Calculate sample means for different sample sizes
sample_means = {source: [] for source in emi_sources.keys()}
for n in num_samples:
    for source, emi_levels in emi_sources.items():
        sample_mean = np.mean(emi_levels[:, :n], axis=1)
        sample_means[source].append(sample_mean)

# Plot the distribution of sample means for each source
plt.figure(figsize=(12, 8))
for source, means in sample_means.items():
    plt.hist(means, bins=30, density=True, alpha=0.5, label=source)

# Plot the normal distribution for comparison
x = np.linspace(0, 15, 1000)
normal_distribution = norm.pdf(x, loc=np.mean(list(emi_sources.values())), scale=np.std(list(emi_sources.values()))/np.sqrt(max(num_samples)))
plt.plot(x, normal_distribution, 'k--', label='Normal Distribution')

plt.title('Distribution of Sample Means (EMI Levels from Different Sources)')
plt.xlabel('Sample Mean (EMI Level)')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate EMI from different sources
num_samples = 10000
mobile_phone_emi = np.random.normal(loc=-70, scale=5, size=num_samples)  # dBm
lightning_emi = np.random.normal(loc=10, scale=2, size=num_samples)  # Strikes per hour
solar_flare_emi = np.random.exponential(scale=5, size=num_samples)  # Exponential distribution
microwave_emi = np.random.gamma(shape=5, scale=2, size=num_samples)  # Watts
ignition_emi = np.random.uniform(low=0, high=5, size=num_samples)  # Spark timing

# Plot the distribution of each EMI separately
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.hist([mobile_phone_emi, lightning_emi, solar_flare_emi, microwave_emi, ignition_emi], bins=100, color=['dodgerblue', 'deeppink', 'gold', 'green', 'orange'], label=['Mobile Phone', 'Lightning', 'Solar Flare', 'Microwave', 'Ignition'], edgecolor='white', alpha=.5, density=True)
plt.xlabel('EMI Level')
plt.ylabel('Density')
plt.title('Distribution of Each EMI Source')
plt.legend()
plt.grid(True)

# Plot the distribution of total EMI
plt.subplot(1, 2, 2)
total_emi = mobile_phone_emi + lightning_emi + solar_flare_emi + microwave_emi + ignition_emi
plt.hist(total_emi, bins=100, color='skyblue', edgecolor='black', alpha=.95, density=True)
plt.xlabel('Total EMI Level (arbitrary units)')
plt.ylabel('Density')
plt.title('Distribution of Total EMI')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate EMI from different sources
num_samples = 100000
mobile_phone_emi = np.random.normal(loc=-70, scale=5, size=num_samples)  # dBm
lightning_emi = np.random.normal(loc=10, scale=2, size=num_samples)  # Strikes per hour
solar_flare_emi = np.random.exponential(scale=5, size=num_samples)  # Exponential distribution
microwave_emi = np.random.gamma(shape=5, scale=2, size=num_samples)  # Watts
ignition_emi = np.random.uniform(low=0, high=5, size=num_samples)  # Spark timing

# Plot the distribution of each EMI separately
plt.figure(figsize=(15, 12))

# Mobile Phone EMI
plt.subplot(3, 2, 1)
plt.hist(mobile_phone_emi, bins=100, color='dodgerblue', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (dBm)')
plt.ylabel('Density')
plt.title('Mobile Phone EMI')
plt.grid(True)

# Lightning EMI
plt.subplot(3, 2, 2)
plt.hist(lightning_emi, bins=100, color='deeppink', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (Strikes per Hour)')
plt.ylabel('Density')
plt.title('Lightning EMI')
plt.grid(True)

# Solar Flare EMI
plt.subplot(3, 2, 3)
plt.hist(solar_flare_emi, bins=100, color='gold', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level')
plt.ylabel('Density')
plt.title('Solar Flare EMI')
plt.grid(True)

# Microwave EMI
plt.subplot(3, 2, 4)
plt.hist(microwave_emi, bins=100, color='green', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (Watts)')
plt.ylabel('Density')
plt.title('Microwave EMI')
plt.grid(True)

# Ignition EMI
plt.subplot(3, 2, 5)
plt.hist(ignition_emi, bins=100, color='orange', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (Spark Timing)')
plt.ylabel('Density')
plt.title('Ignition EMI')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate EMI from different sources
num_samples = 100000
mobile_phone_emi = np.random.normal(loc=-70, scale=5, size=num_samples)  # dBm
lightning_emi = np.random.normal(loc=10, scale=2, size=num_samples)  # Strikes per hour
solar_flare_emi = np.random.exponential(scale=5, size=num_samples)  # Exponential distribution
microwave_emi = np.random.gamma(shape=5, scale=2, size=num_samples)  # Watts
ignition_emi = np.random.uniform(low=0, high=5, size=num_samples)  # Spark timing

# Combined EMI
total_emi = mobile_phone_emi + lightning_emi + solar_flare_emi + microwave_emi + ignition_emi

# Plot the distribution of each EMI separately
plt.figure(figsize=(15, 12))

# Mobile Phone EMI
plt.subplot(3, 2, 1)
plt.hist(mobile_phone_emi, bins=100, color='dodgerblue', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (dBm)')
plt.ylabel('Density')
plt.title('Mobile Phone EMI')
plt.grid(True)

# Lightning EMI
plt.subplot(3, 2, 2)
plt.hist(lightning_emi, bins=100, color='deeppink', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (Strikes per Hour)')
plt.ylabel('Density')
plt.title('Lightning EMI')
plt.grid(True)

# Solar Flare EMI
plt.subplot(3, 2, 3)
plt.hist(solar_flare_emi, bins=100, color='gold', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level')
plt.ylabel('Density')
plt.title('Solar Flare EMI')
plt.grid(True)

# Microwave EMI
plt.subplot(3, 2, 4)
plt.hist(microwave_emi, bins=100, color='green', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (Watts)')
plt.ylabel('Density')
plt.title('Microwave EMI')
plt.grid(True)

# Ignition EMI
plt.subplot(3, 2, 5)
plt.hist(ignition_emi, bins=100, color='orange', edgecolor='white', alpha=0.7, density=True)
plt.xlabel('EMI Level (Spark Timing)')
plt.ylabel('Density')
plt.title('Ignition EMI')
plt.grid(True)

# Combined EMI
plt.subplot(3, 2, 6)
plt.hist(total_emi, bins=100, color='skyblue', edgecolor='black', alpha=0.7, density=True)
plt.xlabel('Total EMI Level (arbitrary units)')
plt.ylabel('Density')
plt.title('Combined EMI')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate data
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 4, 100)
X, Y = np.meshgrid(X, Y)
Z = np.exp(-np.sqrt(X**2 + Y**2))

# Create the plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the mesh
ax.plot_surface(X, Y, Z, cmap='viridis')

# Plot the shaded region
ax.plot([0, 0], [1, 3], [0, 0], color='red')  # Vertical line at x=0
ax.plot([-5, 5], [0, 0], [0, 0], color='blue')  # Horizontal line at y=0

# Draw vertical dashed lines from the corners of the shaded region to the mesh plot
ax.plot([-5, -5], [0, 0], [0, 0], color='red', linestyle='--')  # Left vertical dashed line
ax.plot([5, 5], [0, 0], [0, 0], color='red', linestyle='--')  # Right vertical dashed line
ax.plot([0, 0], [-5, -5], [0, 0], color='blue', linestyle='--')  # Bottom vertical dashed line
ax.plot([0, 0], [5, 5], [0, 0], color='blue', linestyle='--')  # Top vertical dashed line

plt.show()

# %%
ax.plot([1, -5], [0, 0], [0, 0], color='red', linestyle='--')  # Left vertical dashed line
ax.plot([5, 5], [0, 0], [0, 0], color='red', linestyle='--')  # Right vertical dashed line
ax.plot([0, 0], [-5, -5], [0, 0], color='blue', linestyle='--')  # Bottom vertical dashed line
ax.plot([0, 0], [5, 5], [0, 0], color='blue', linestyle='--')  # Top vertical dashed line

plt.show()

# %%
fig = plt.figure()

# %%
ax.plot([-5, -5], [0, 0], [0, 0], color='red', linestyle='--')  # Left vertical dashed line
ax.plot([5, 5], [0, 0], [0, 0], color='red', linestyle='--')  # Right vertical dashed line
ax.plot([0, 0], [-5, -5], [0, 0], color='blue', linestyle='--')  # Bottom vertical dashed line
ax.plot([0, 0], [5, 5], [0, 0], color='blue', linestyle='--')  # Top vertical dashed line

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

# Parameters
mu_x = 3
mu_y = 2
var_x = 4
var_y = 1
cov_xy = 1.5

# Define the mean vector and covariance matrix
mean = [mu_x, mu_y]
covariance = [[var_x, cov_xy], [cov_xy, var_y]]

# Create a grid of x and y values
x = np.linspace(0, 5, 100)
y = np.linspace(0, 4, 100)
X, Y = np.meshgrid(x, y)
pos = np.dstack((X, Y))

# Create the bivariate normal distribution
mvn = multivariate_normal(mean=mean, cov=covariance)

# Calculate the bivariate PDF
Z = mvn.pdf(pos)

# Plot the bivariate PDF using a mesh plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.7)  # Set alpha value for translucency

# Shade the area under the curve for X and Y bounds
x_shade = np.linspace(1, 5, 100)
y_shade = np.linspace(1, 3, 100)
X_shade, Y_shade = np.meshgrid(x_shade, y_shade)
ax.plot_surface(X_shade, Y_shade, np.zeros_like(X_shade), color='skyblue', alpha=1)

# Draw vertical dashed lines from the corners of the shaded region to the mesh plot
ax.plot([1, 1], [1, 1], [0.06, 0.06], color='red', linestyle='--')  # Left vertical dashed line
#ax.plot([5, 5], [1, 1], [0.06, 0.06], color='red', linestyle='--')  # Right vertical dashed line
#ax.plot([1, 1], [3, 3], [0.06, 0.06], color='blue', linestyle='--')  # Bottom vertical dashed line
#ax.plot([5, 1], [3, 3], [0.06, 0.06], color='blue', linestyle='--')  # Top vertical dashed line


ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Probability Density')
ax.set_title('Bivariate Gaussian PDF')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
sigma_X = 1

# Define range for x values
x_values = np.linspace(0, 2, 100)

# Calculate corresponding y values
y_values = np.exp(-x_values / (2 * sigma_X)) / (sigma_X * np.sqrt(2 * np.pi * x_values))

# Plot the function
plt.plot(x_values, y_values, label=r'$f_Y(y)=\frac{1}{\sigma_X \sqrt{2\pi y}} \exp \left( - \frac{y}{2 \sigma_X} \right)$')
plt.xlabel('x')
plt.ylabel('$f_Y(y)$')
#plt.title('Plot of Function')
#plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/dg/52hsjgqx35sdp0lyrfrkhwbr0000gr/T/ipykernel_25851/4007365040.py:11: RuntimeWarning: divide by zero encountered in divide
#   y_values = np.exp(-x_values / (2 * sigma_X)) / (sigma_X * np.sqrt(2 * np.pi * x_values))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
K = 2.0  # Some constant
alpha = 0.5  # Decay rate

# Define the time vector
t = np.linspace(0, 10, 1000)  # Time range from 0 to 10 seconds

# Define the function h(t)
h_t = (1 / np.sqrt(K)) * np.exp(-alpha * t) * (t >= 0)

# Plot the function
plt.plot(t, h_t, label=r'$h(t) = \frac{1}{\sqrt{K}}e^{-\alpha t} u(t)$')
plt.xlabel('Time (t)')
plt.ylabel('h(t)')
#plt.title('Plot of h(t)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.integrate import quad

# Define the function to integrate
def integrand(y):
    return 1 / (2*np.sqrt(2 * np.pi)) * np.exp(-y**2 / 4)

# Perform the numerical integration
result, _ = quad(integrand, 0, np.inf)

print("Numerical result:", result)
# Out:
# Numerical result: 0.3535533905932738

# %%
import numpy as np
from scipy.integrate import quad

# Define the integrand function
def integrand(y):
    return 1 / (2 * np.sqrt(2 * np.pi)) * np.exp(-y**2 / 4)

# Perform the numerical integration
result, _ = quad(integrand, 0, np.inf)

print("Numerical result:", result)
# Out:
# Numerical result: 0.3535533905932738

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of x and y values
x_values = np.linspace(-4, 4, 1000)
y_values = np.linspace(1, 4, 1000)

# Define the probability density functions
def f_X(x):
    return 1 / (2 * np.sqrt(2 * np.pi)) * np.exp(-x**2 / 8)

def f_Y(y):
    return 1 / np.sqrt(2 * np.pi) * np.exp(-y**2 / 8)

# Calculate the corresponding probability density values
f_X_values = f_X(x_values)
f_Y_values = f_Y(y_values)

# Plot f_X(x)
plt.plot(x_values, f_X_values, label=r'$f_X(x) = \frac{1}{2\sqrt{2\pi}} e^{-\frac{x^2}{8}}$')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Probability Density Function $f_X(x)$')
plt.grid(True)
plt.legend()
plt.show()

# Plot f_Y(y)
plt.plot(y_values, f_Y_values, label=r'$f_Y(y) = \frac{1}{\sqrt{2\pi}} e^{-\frac{y^2}{8}}$')
plt.xlabel('y')
plt.ylabel('Probability Density')
plt.title('Probability Density Function $f_Y(y)$')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of x and y values
x_values = np.linspace(-5, 5, 1000)
y_values = np.linspace(0, 5, 1000)

# Define the probability density functions
def f_X(x):
    return 1 / (2 * np.sqrt(2 * np.pi)) * np.exp(-x**2 / 8)

def f_Y(y):
    return 1 / np.sqrt(2 * np.pi) * np.exp(-y**2 / 8)

# Calculate the corresponding probability density values
f_X_values = f_X(x_values)
f_Y_values = f_Y(y_values)

# Plot f_X(x) and f_Y(y) on the same axes
plt.plot(x_values, f_X_values, label=r'$f_X(x) = \frac{1}{2\sqrt{2\pi}} e^{-\frac{x^2}{8}}$')
plt.plot(y_values, f_Y_values, label=r'$f_Y(y) = \frac{1}{\sqrt{2\pi}} e^{-\frac{y^2}{8}}$')

plt.xlabel('x / y')
plt.ylabel('Probability Density')
plt.title('Probability Density Functions $f_X(x)$ and $f_Y(y)$')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of x values
x_values = np.linspace(-4, 4, 1000)

# Compute the corresponding probability density values for f_X(x)
f_X_values = 1 / (2 * np.sqrt(2 * np.pi)) * np.exp(-x_values**2 / 8)

# Plot f_X(x)
plt.plot(x_values, f_X_values, label=r'$f_X(x) = \frac{1}{2\sqrt{2\pi}} e^{-\frac{x^2}{8}}$')

# Define the range of y values
y_values = np.linspace(1, 4, 1000)

# Compute the corresponding probability density values for f_Y(y)
f_Y_values = 1 / np.sqrt(2 * np.pi) * np.exp(-y_values**2 / 8)

# Plot f_Y(y)
plt.plot(y_values, f_Y_values, label=r'$f_Y(y) = \frac{1}{\sqrt{2\pi}} e^{-\frac{y^2}{8}}$')

# Set plot labels and title
plt.xlabel('x / y')
plt.ylabel('Probability Density')
plt.title('Numerically Computed Probability Density Functions $f_X(x)$ and $f_Y(y)$')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Generate 1000 random samples from a normal distribution for X
mean_X = 0
std_X = 2
X_samples = np.random.normal(mean_X, std_X, 1000)
XY_samples = np.random.normal(mean_X, std_X, 2000)

# Calculate absolute values to obtain samples for Y
Y_samples = np.abs(XY_samples)

# Plot histograms of X and Y on the same axes
plt.hist(X_samples, bins=30, alpha=0.5, color='b', label='X')
plt.hist(Y_samples, bins=30, alpha=0.5, color='r', label='Y')

# Set plot labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histograms of X and Y')
plt.grid(True)
plt.legend()
plt.show()
